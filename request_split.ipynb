# %%
print("asma shaik")
# Out:
# asma shaik

# %%
print("This is a GRT mrng")
print("hiii sri sir")
print("forgetting to press shift before enter!!!")
# Out:
# This is a GRT mrng
# hiii sri sir
# forgetting to press shift before enter!!!

# %%
import requests

# %%
url="https://www.hashicorp.com/.well-known/pgp-key.txt"

# %%
resp=requests.get(url)

# %%
resp
# Out:
# <Response [200]>

# %%
resp.text
# Out:
# '1949-01,114\n1949-02,120\n1949-03,134\n1949-04,67\n1949-05,123\n1949-06,137\n1949-07,150\n1949-08,50\n1949-09,138\n1949-10,121\n1949-11,106\n1949-12,34\n1950-01,117\n1950-02,128\n1950-03,143\n1950-04,137\n1950-05,127\n1950-06,151\n1950-07,172\n1950-08,172\n1950-09,159\n1950-10,135\n1950-11,116\n1950-12,142\n1951-01,147\n1951-02,152\n1951-03,180\n1951-04,165\n1951-05,174\n1951-06,123\n1951-07,154\n1951-08,201\n1951-09,184\n1951-10,162\n1951-11,146\n1951-12,166\n1952-01,171\n1952-02,180\n1952-03,193\n1952-04,181\n1952-05,183\n1952-06,218\n1952-07,230\n1952-08,242\n1952-09,209\n1952-10,191\n1952-11,172\n1952-12,194\n1953-01,196\n1953-02,196\n1953-03,236\n1953-04,235\n1953-05,229\n1953-06,243\n1953-07,264\n1953-08,272\n1953-09,237\n1953-10,211\n1953-11,180\n1953-12,201\n1954-01,204\n1954-02,188\n1954-03,235\n1954-04,227\n1954-05,234\n1954-06,245\n1954-07,302\n1954-08,293\n1954-09,259\n1954-10,229\n1954-11,203\n1954-12,229\n1955-01,242\n1955-02,233\n1955-03,267\n1955-04,269\n1955-05,270\
# ...

# %% [raw]
# txt=resp.txt

# %% [raw]
# txt[0:100]

# %%
import requests

# %%
url="https://raw.githubusercontent.com/srisreedhar/DataSets/refs/heads/master/Customers.csv"

# %%
resp=requests.get(url)

# %%
resp
# Out:
# <Response [200]>

# %%
resp.text
# Out:
# '1949-01,114\n1949-02,120\n1949-03,134\n1949-04,67\n1949-05,123\n1949-06,137\n1949-07,150\n1949-08,50\n1949-09,138\n1949-10,121\n1949-11,106\n1949-12,34\n1950-01,117\n1950-02,128\n1950-03,143\n1950-04,137\n1950-05,127\n1950-06,151\n1950-07,172\n1950-08,172\n1950-09,159\n1950-10,135\n1950-11,116\n1950-12,142\n1951-01,147\n1951-02,152\n1951-03,180\n1951-04,165\n1951-05,174\n1951-06,123\n1951-07,154\n1951-08,201\n1951-09,184\n1951-10,162\n1951-11,146\n1951-12,166\n1952-01,171\n1952-02,180\n1952-03,193\n1952-04,181\n1952-05,183\n1952-06,218\n1952-07,230\n1952-08,242\n1952-09,209\n1952-10,191\n1952-11,172\n1952-12,194\n1953-01,196\n1953-02,196\n1953-03,236\n1953-04,235\n1953-05,229\n1953-06,243\n1953-07,264\n1953-08,272\n1953-09,237\n1953-10,211\n1953-11,180\n1953-12,201\n1954-01,204\n1954-02,188\n1954-03,235\n1954-04,227\n1954-05,234\n1954-06,245\n1954-07,302\n1954-08,293\n1954-09,259\n1954-10,229\n1954-11,203\n1954-12,229\n1955-01,242\n1955-02,233\n1955-03,267\n1955-04,269\n1955-05,270\
# ...

# %%
data=resp.text

# %%
data[0:100]
# Out:
# '1949-01,114\n1949-02,120\n1949-03,134\n1949-04,67\n1949-05,123\n1949-06,137\n1949-07,150\n1949-08,50\n1949-0'

# %%
lines=data.split('\n')

# %%
lines[0:20]
# Out:
# ['1949-01,114',
#  '1949-02,120',
#  '1949-03,134',
#  '1949-04,67',
#  '1949-05,123',
#  '1949-06,137',
#  '1949-07,150',
#  '1949-08,50',
#  '1949-09,138',
#  '1949-10,121',
#  '1949-11,106',
#  '1949-12,34',
#  '1950-01,117',
#  '1950-02,128',
#  '1950-03,143',
#  '1950-04,137',
#  '1950-05,127',
#  '1950-06,151',
#  '1950-07,172',
#  '1950-08,172']

# %%
lines[0]
# Out:
# '1949-01,114'

# %%
resp.content
# Out:
# b'1949-01,114\n1949-02,120\n1949-03,134\n1949-04,67\n1949-05,123\n1949-06,137\n1949-07,150\n1949-08,50\n1949-09,138\n1949-10,121\n1949-11,106\n1949-12,34\n1950-01,117\n1950-02,128\n1950-03,143\n1950-04,137\n1950-05,127\n1950-06,151\n1950-07,172\n1950-08,172\n1950-09,159\n1950-10,135\n1950-11,116\n1950-12,142\n1951-01,147\n1951-02,152\n1951-03,180\n1951-04,165\n1951-05,174\n1951-06,123\n1951-07,154\n1951-08,201\n1951-09,184\n1951-10,162\n1951-11,146\n1951-12,166\n1952-01,171\n1952-02,180\n1952-03,193\n1952-04,181\n1952-05,183\n1952-06,218\n1952-07,230\n1952-08,242\n1952-09,209\n1952-10,191\n1952-11,172\n1952-12,194\n1953-01,196\n1953-02,196\n1953-03,236\n1953-04,235\n1953-05,229\n1953-06,243\n1953-07,264\n1953-08,272\n1953-09,237\n1953-10,211\n1953-11,180\n1953-12,201\n1954-01,204\n1954-02,188\n1954-03,235\n1954-04,227\n1954-05,234\n1954-06,245\n1954-07,302\n1954-08,293\n1954-09,259\n1954-10,229\n1954-11,203\n1954-12,229\n1955-01,242\n1955-02,233\n1955-03,267\n1955-04,269\n1955-05,270
# ...

# %%
sum([1,2,3,4,50])
# Out:
# 60

# %%
sum([1,12,123])
# Out:
# 136
