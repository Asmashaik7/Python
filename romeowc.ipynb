# %%
import requests
import os

# %%
url="https://ia800200.us.archive.org/27/items/romeojuliet01shak/romeojuliet01shak_djvu.txt"

# %%
resp = requests.get(url).text

# %%
data = resp.lower() #data is full text of the url

# %%
d=data.split("\n")[:100]
d
# Out:
# ['romeo  and  juliet. ',
#  '',
#  '',
#  'green  room  sdition ',
#  '',
#  '',
#  'romeo  and  juliet ',
#  '',
#  'by ',
#  '',
#  'william  shakespeare ',
#  '',
#  '',
#  'illustrated  by  photographs  from  life  of  maude  adams, ',
#  'and  oth^r  members  of  her  company,  by  byron  and ',
#  'sarony,  and  also  by  illtistrations  by  andriolli    ^    «^ ',
#  '',
#  '',
#  'new  york  and  boston  ^    ^ ',
#  '',
#  'h.  m.  caldwell  company ',
#  '^     s     ,^     ^     ,^     publishers ',
#  '',
#  '',
#  'l- ',
#  '',
#  '',
#  '38524 ',
#  '',
#  '^ * t>pa^y  of  cj^^jil^ ',
#  '',
#  '"two  copifs  recfived ',
#  '',
#  'aug  20  1900 ',
#  '',
#  'copyright  entry ',
#  '',
#  '10^  t(^  s^ ',
#  '',
#  '',
#  'second  copy. ',
#  '',
#  'delivered  to ',
#  '',
#  'orolr  division, ',
#  '',
#  'sep    6    1900 ',
#  '',
#  '',
#  'copyright,  i88y. ',
#  'by  samuel  e.  cassino. ',
#  '',
#  'copyright,  igoo. ',
#  'by  h.  m.  caldwell  co. ',
#  '',
# ...

# %%
newdata=[]
for everyline in d:
    if everyline!='':
        newdata.append(everyline.strip())
newdata[:100]
# Out:
# ['romeo  and  juliet.',
#  'green  room  sdition',
#  'romeo  and  juliet',
#  'by',
#  'william  shakespeare',
#  'illustrated  by  photographs  from  life  of  maude  adams,',
#  'and  oth^r  members  of  her  company,  by  byron  and',
#  'sarony,  and  also  by  illtistrations  by  andriolli    ^    «^',
#  'new  york  and  boston  ^    ^',
#  'h.  m.  caldwell  company',
#  '^     s     ,^     ^     ,^     publishers',
#  'l-',
#  '38524',
#  '^ * t>pa^y  of  cj^^jil^',
#  '"two  copifs  recfived',
#  'aug  20  1900',
#  'copyright  entry',
#  '10^  t(^  s^',
#  'second  copy.',
#  'delivered  to',
#  'orolr  division,',
#  'sep    6    1900',
#  'copyright,  i88y.',
#  'by  samuel  e.  cassino.',
#  'copyright,  igoo.',
#  'by  h.  m.  caldwell  co.',
#  '74121',
#  'romeo  and  juliet',
#  'facsimile',
#  'of    the',
#  'original     programme',
#  'the    cast',
#  "as  -produced  at  the  empire  'theatre^  new  tork^  may  8th,  isgg.",
# ...

# %%
words=list()

# %%
for everyline in newdata:
    words.extend(everyline.split())
words[:100]
# Out:
# ['romeo',
#  'and',
#  'juliet.',
#  'green',
#  'room',
#  'sdition',
#  'romeo',
#  'and',
#  'juliet',
#  'by',
#  'william',
#  'shakespeare',
#  'illustrated',
#  'by',
#  'photographs',
#  'from',
#  'life',
#  'of',
#  'maude',
#  'adams,',
#  'and',
#  'oth^r',
#  'members',
#  'of',
#  'her',
#  'company,',
#  'by',
#  'byron',
#  'and',
#  'sarony,',
#  'and',
#  'also',
#  'by',
#  'illtistrations',
#  'by',
#  'andriolli',
#  '^',
#  '«^',
#  'new',
#  'york',
#  'and',
#  'boston',
#  '^',
#  '^',
#  'h.',
#  'm.',
#  'caldwell',
#  'company',
#  '^',
#  's',
#  ',^',
#  '^',
#  ',^',
#  'publishers',
#  'l-',
#  '38524',
#  '^',
#  '*',
#  't>pa^y',
#  'of',
#  'cj^^jil^',
#  '"two',
#  'copifs',
#  'recfived',
#  'aug',
#  '20',
#  '1900',
#  'copyright',
#  'entry',
#  '10^',
#  't(^',
#  's^',
#  'second',
#  'copy.',
#  'delivered',
#  'to',
#  'orolr',
#  'division,',
#  'sep',
#  '6',
#  '1900',
#  'copyright,',
#  'i88y.',
#  'by',
#  'samuel',
#  'e.',
# ...

# %%
len(words)
# Out:
# 418

# %%
wordcount=dict()

# %%
for everyword in words:
    if everyword not in wordcount:
        wordcount[everyword]=1
    else:
        wordcount[everyword]=wordcount[everyword]+1
wordcount
# Out:
# {'romeo': 6,
#  'and': 11,
#  'juliet.': 1,
#  'green': 1,
#  'room': 1,
#  'sdition': 1,
#  'juliet': 2,
#  'by': 7,
#  'william': 2,
#  'shakespeare': 1,
#  'illustrated': 1,
#  'photographs': 1,
#  'from': 1,
#  'life': 1,
#  'of': 9,
#  'maude': 2,
#  'adams,': 2,
#  'oth^r': 1,
#  'members': 1,
#  'her': 1,
#  'company,': 1,
#  'byron': 1,
#  'sarony,': 1,
#  'also': 1,
#  'illtistrations': 1,
#  'andriolli': 1,
#  '^': 6,
#  '«^': 1,
#  'new': 2,
#  'york': 1,
#  'boston': 1,
#  'h.': 2,
#  'm.': 2,
#  'caldwell': 2,
#  'company': 1,
#  's': 1,
#  ',^': 2,
#  'publishers': 1,
#  'l-': 1,
#  '38524': 1,
#  '*': 1,
#  't>pa^y': 1,
#  'cj^^jil^': 1,
#  '"two': 1,
#  'copifs': 1,
#  'recfived': 1,
#  'aug': 1,
#  '20': 1,
#  '1900': 2,
#  'copyright': 1,
#  'entry': 1,
#  '10^': 1,
#  't(^': 1,
#  's^': 1,
#  'second': 1,
#  'copy.': 1,
#  'delivered': 1,
#  'to': 8,
#  'orolr': 1,
#  'division,': 1,
#  'sep': 1,
#  '6': 1,
#  'copyright,': 2,
#  'i88y.': 1,
#  'samuel': 1,
# ...

# %%
len(words)
# Out:
# 209

# %%
len(wordcount)
# Out:
# 138

# %%
spl_chars=[]
count=0
for everyword in words:
    if everyword=='"':
        spl_chars.append(everyword)
        count=count+1
        words.remove(everyword)
    elif everyword==":":
        spl_chars.append(everyword)
        count=count+1
        words.remove(':')
    elif everyword=='?':
        spl_chars.append(everyword)
        count=count+1
        words.remove(everyword)
    elif everyword=="'":
        spl_chars.append(everyword)
        count=count+1
        words.remove(everyword)
    elif everyword==';':
        spl_chars.append(everyword)
        count=count+1
        words.remove(everyword)
    elif everyword==',':
        spl_chars.append(everyword)
        count=count+1
        words.remove(everyword)
    elif everyword=='.':
        spl_chars.append(everyword)
        count=count+1
        words.remove(everyword)
    elif everyword=='[':
        spl_chars.append(everyword)
        count=count+1
        words.remove(everyword)
    elif everyword==']':
        spl_chars.append(everyword)
        count=count+1
        words.remove(everyword)
    elif everyword=='\\':
        spl_chars.append(everyword)
        count=count+1
        words.remove(everyword)
    elif everyword=='(':
        spl_chars.append(everyword)
        count=count+1
        words.remove(everyword)
    elif everyword==')':
        spl_chars.append(everyword)
        count=count+1
        words.remove(everyword)
    elif everyword=='':
        spl_chars.append(everyword)
        count=count+1
        words.remove(everyword)
    elif everyword=='/':
        spl_chars.append(everyword)
        count=count+1
        words.remove(everyword)
    elif everyword=='{':
        spl_chars.append(everyword)
        count=count+1
        words.remove(everyword)
    elif everyword=='}':
        spl_chars.append(everyword)
        count=count+1
        words.remove(everyword)
    elif everyword=='!':
        spl_chars.append(everyword)
        count=count+1
        words.remove(everyword)
    elif everyword=='@':
        spl_chars.append(everyword)
        count=count+1
        words.remove(everyword)
    elif everyword=='#':
        spl_chars.append(everyword)
        count=count+1
        words.remove(everyword)
    elif everyword=='$':
        spl_chars.append(everyword)
        count=count+1
        words.remove(everyword)
    elif everyword=='%':
        spl_chars.append(everyword)
        count=count+1
        words.remove(everyword)
    elif everyword=='^':
        spl_chars.append(everyword)
        count=count+1
        words.remove(everyword)
    elif everyword=='&':
        spl_chars.append(everyword)
        count=count+1
        words.remove(everyword)
    elif everyword=='*':
        spl_chars.append(everyword)
        count=count+1
        words.remove(everyword)
    else:
        count=count+1
        words.remove(everyword)

print("words :",words)
print("spl characters :", spl_chars)
print("spl characters count :",count)
# Out:
# words : ['green', 'sdition', 'shakespeare', 'from', 'oth^r', 'company,', 'byron', 'sarony,', 'also', 'by', 'illtistrations', 'by', 'andriolli', '«^', 'york', 'boston', 'm.', 'company', 's', '^', 'publishers', '38524', '^', '*', 'of', '"two', 'recfived', '20', 'copyright', '10^', 's^', 'copy.', 'division,', '6', 'copyright,', 'by', 'e.', 'copyright,', 'by', 'm.', 'co.', 'juliet', 'of', 'original', 'at', 'empire', 'new', 'may', 'isgg.', 'maude', 'adams,', 'in', 'special', 'of', 'tragedy', 'of', '"', 'romeo', 'faversham', 'romeo,', 'and', 'james', 'hackett', 'as', 'mercutio.', 'arrangement', 'daniel', 'dramatis', 'escalus,', 'of', 'paris,', 'young', 'heads', 'of', 'two', 'at', 'variance', 'with', 'each', '[', 'old', 'of', 'the', 'capulet', 'romeo,', 'montague', 'mercutio,', 'kinsman', 'the', 'prince,', 'and', 'friend', 'romeo', 'nephew', 'to', 'montague,', 'and', 'friend', 'to', 'romeo', 'nephew', 'to', 'lady', 'capulet']
# spl characters : ['^', '^', '^', '^', ')', '\\']
# ...

# %%
len(words)
# Out:
# 52

# %%
len(spl_chars)
# Out:
# 2
